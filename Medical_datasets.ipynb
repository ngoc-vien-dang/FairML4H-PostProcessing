# %%
import pandas as pd
import numpy as np
import os
import pickle

file_path = 'Add_XGB_DNN_Trade-off_overall_data_medical.pkl'
with open(file_path, 'rb') as f:
    medical_df = pickle.load(f)
# Out:
# Mounted at /content/drive

# %%
medical_df['Overall_Overall'][['class_imbalance_degree', 'unprivileged_representation_degree','method', 'F1-score', 'BAcc', 'EOp', 'EOd']]
# Out:
#    class_imbalance_degree unprivileged_representation_degree   method  \
# 64                Overall                            Overall      CPP
# 65                Overall                            Overall      EPP
# 70                Overall                            Overall      ROC
# 69                Overall                            Overall     PSTA
# 66                Overall                            Overall     FACT
# 67                Overall                            Overall    GSTAR
# 68                Overall                            Overall      MAB
# 71                Overall                            Overall  Average
#
#            F1-score             BAcc              EOp              EOd
# 64   -0.040 (-8.2%)   -0.050 (-6.5%)   -0.006 (-7.5%)    0.080 (40.5%)
# 65  -0.073 (-13.4%)   -0.066 (-8.7%)  -0.093 (-48.6%)  -0.110 (-56.5%)
# 70   -0.007 (-1.0%)     0.006 (1.1%)  -0.081 (-39.1%)  -0.070 (-28.8%)
# ...

# %%
medical_df['High_High'][['class_imbalance_degree', 'unprivileged_representation_degree','method', 'F1-score', 'BAcc', 'EOp', 'EOd']]
# Out:
#   class_imbalance_degree unprivileged_representation_degree   method  \
# 1                   High                               High      CPP
# 2                   High                               High      EPP
# 7                   High                               High      ROC
# 6                   High                               High     PSTA
# 3                   High                               High     FACT
# 4                   High                               High    GSTAR
# 5                   High                               High      MAB
# 8                   High                               High  Average
#
#           F1-score             BAcc              EOp              EOd
# 1  -0.083 (-15.5%)   -0.054 (-7.5%)   -0.002 (-9.7%)  -0.043 (-22.9%)
# 2  -0.132 (-24.4%)  -0.083 (-11.2%)  -0.191 (-68.8%)  -0.230 (-78.5%)
# 7   -0.023 (-4.3%)     0.014 (2.1%)  -0.179 (-64.4%)  -0.168 (-51.4%)
# ...

# %%
medical_df['High_Low'][['class_imbalance_degree', 'unprivileged_representation_degree','method', 'F1-score', 'BAcc', 'EOp', 'EOd']]
# Out:
#    class_imbalance_degree unprivileged_representation_degree   method  \
# 10                   High                                Low      CPP
# 11                   High                                Low      EPP
# 16                   High                                Low      ROC
# 15                   High                                Low     PSTA
# 12                   High                                Low     FACT
# 13                   High                                Low    GSTAR
# 14                   High                                Low      MAB
# 17                   High                                Low  Average
#
#             F1-score             BAcc               EOp               EOd
# 10    -0.002 (-1.0%)   -0.014 (-1.9%)   -0.036 (-40.7%)   -0.023 (-34.6%)
# 11    -0.008 (-4.2%)   -0.024 (-3.4%)   -0.037 (-36.9%)   -0.027 (-39.0%)
# 16    -0.012 (-6.8%)     0.005 (0.7%)   -0.036 (-43.3%)   -0.013 (-13.2%)
# ...

# %%
medical_df['High_Medium'][['class_imbalance_degree', 'unprivileged_representation_degree','method', 'F1-score', 'BAcc', 'EOp', 'EOd']]
# Out:
#    class_imbalance_degree unprivileged_representation_degree   method  \
# 19                   High                             Medium      CPP
# 20                   High                             Medium      EPP
# 25                   High                             Medium      ROC
# 24                   High                             Medium     PSTA
# 21                   High                             Medium     FACT
# 22                   High                             Medium    GSTAR
# 23                   High                             Medium      MAB
# 26                   High                             Medium  Average
#
#            F1-score             BAcc              EOp              EOd
# 19  -0.060 (-18.0%)   -0.045 (-6.4%)  -0.122 (-62.9%)  -0.091 (-54.0%)
# 20  -0.061 (-18.5%)   -0.043 (-6.2%)  -0.132 (-71.8%)  -0.129 (-80.4%)
# 25     0.021 (8.8%)     0.032 (5.5%)  -0.112 (-61.5%)  -0.074 (-37.3%)
# ...

# %%
medical_df['Low_High'][['class_imbalance_degree', 'unprivileged_representation_degree','method', 'F1-score', 'BAcc', 'EOp', 'EOd']]
# Out:
#    class_imbalance_degree unprivileged_representation_degree   method  \
# 28                    Low                               High      CPP
# 29                    Low                               High      EPP
# 34                    Low                               High      ROC
# 33                    Low                               High     PSTA
# 30                    Low                               High     FACT
# 31                    Low                               High    GSTAR
# 32                    Low                               High      MAB
# 35                    Low                               High  Average
#
#            F1-score             BAcc              EOp              EOd
# 28   -0.007 (-0.9%)   -0.013 (-1.6%)    0.026 (25.3%)   0.241 (164.5%)
# 29   -0.050 (-6.1%)  -0.098 (-12.2%)  -0.032 (-29.8%)  -0.057 (-32.5%)
# 34   -0.011 (-1.4%)   -0.007 (-0.8%)    0.020 (21.0%)   -0.006 (-1.1%)
# ...

# %%
medical_df['Low_Medium'][['class_imbalance_degree', 'unprivileged_representation_degree','method', 'F1-score', 'BAcc', 'EOp', 'EOd']]
# Out:
#    class_imbalance_degree unprivileged_representation_degree   method  \
# 37                    Low                             Medium      CPP
# 38                    Low                             Medium      EPP
# 43                    Low                             Medium      ROC
# 42                    Low                             Medium     PSTA
# 39                    Low                             Medium     FACT
# 40                    Low                             Medium    GSTAR
# 41                    Low                             Medium      MAB
# 44                    Low                             Medium  Average
#
#            F1-score             BAcc              EOp              EOd
# 37   -0.047 (-5.7%)  -0.123 (-15.3%)    0.105 (50.6%)   0.315 (149.8%)
# 38  -0.113 (-13.7%)  -0.083 (-10.3%)  -0.072 (-36.0%)  -0.110 (-52.3%)
# 43   -0.011 (-1.3%)   -0.015 (-1.8%)  -0.097 (-47.1%)  -0.087 (-40.9%)
# ...
