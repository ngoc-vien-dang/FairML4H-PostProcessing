# %%
import pickle
file_path = 'Trade-off_medical_data.pkl'
# Load the dictionary
with open(file_path, 'rb') as f:
    medical_df = pickle.load(f)

# %%
medical_df['High_High']
# Out:
#   class_imbalance_degree unprivileged_representation_degree  \
# 0                   High                               High
# 1                   High                               High
# 2                   High                               High
# 3                   High                               High
# 4                   High                               High
# 5                   High                               High
# 6                   High                               High
#
#                method         F1-score             BAcc              EOp  \
# 0                 CPP   -0.052 (-9.2%)   -0.051 (-6.5%)  -0.047 (-27.7%)
# 1                 EPP  -0.153 (-27.6%)  -0.115 (-14.8%)  -0.212 (-78.1%)
# 2                 ROC   -0.029 (-5.2%)   -0.018 (-2.3%)  -0.194 (-71.8%)
# 3                PSTA   -0.030 (-5.4%)   -0.004 (-0.5%)  -0.100 (-43.1%)
# 4                FACT  -0.554 (-99.4%)  -0.274 (-35.4%)  -0.252 (-98.9%)
# ...

# %%
medical_df['High_Low']
# Out:
#    class_imbalance_degree unprivileged_representation_degree  \
# 7                    High                                Low
# 8                    High                                Low
# 9                    High                                Low
# 10                   High                                Low
# 11                   High                                Low
# 12                   High                                Low
# 13                   High                                Low
#
#                 method          F1-score             BAcc               EOp  \
# 7                  CPP    -0.001 (-0.4%)   -0.009 (-1.2%)   -0.027 (-48.3%)
# 8                  EPP    -0.005 (-2.5%)   -0.015 (-2.0%)   -0.019 (-33.2%)
# 9                  ROC    -0.007 (-3.6%)     0.001 (0.1%)   -0.018 (-33.1%)
# 10                PSTA    -0.002 (-1.0%)     0.000 (0.0%)   -0.035 (-64.5%)
# 11                FACT  -0.178 (-100.0%)  -0.229 (-31.4%)  -0.053 (-100.0%)
# ...

# %%
medical_df['High_Medium']
# Out:
#    class_imbalance_degree unprivileged_representation_degree  \
# 14                   High                             Medium
# 15                   High                             Medium
# 16                   High                             Medium
# 17                   High                             Medium
# 18                   High                             Medium
# 19                   High                             Medium
# 20                   High                             Medium
#
#                 method         F1-score             BAcc              EOp  \
# 14                 CPP   -0.035 (-7.7%)   -0.046 (-6.3%)  -0.149 (-67.9%)
# 15                 EPP  -0.050 (-12.1%)   -0.048 (-6.5%)  -0.155 (-73.8%)
# 16                 ROC   -0.011 (-2.9%)   -0.003 (-0.5%)  -0.138 (-67.1%)
# 17                PSTA   -0.013 (-3.2%)   -0.002 (-0.3%)  -0.142 (-64.7%)
# 18                FACT  -0.408 (-99.8%)  -0.242 (-32.6%)  -0.188 (-99.2%)
# ...

# %%
medical_df['Low_High']
# Out:
#    class_imbalance_degree unprivileged_representation_degree  \
# 21                    Low                               High
# 22                    Low                               High
# 23                    Low                               High
# 24                    Low                               High
# 25                    Low                               High
# 26                    Low                               High
# 27                    Low                               High
#
#                 method        F1-score             BAcc              EOp  \
# 21                 CPP  -0.009 (-1.1%)   -0.015 (-1.8%)    0.027 (26.5%)
# 22                 EPP  -0.049 (-5.9%)  -0.095 (-11.6%)  -0.029 (-29.0%)
# 23                 ROC  -0.011 (-1.3%)   -0.007 (-0.9%)    0.032 (32.2%)
# 24                PSTA    0.006 (0.7%)     0.003 (0.4%)  -0.014 (-13.8%)
# 25                FACT  -0.040 (-4.8%)   -0.027 (-3.3%)   0.311 (308.2%)
# ...

# %%
medical_df['Low_Medium']
# Out:
#    class_imbalance_degree unprivileged_representation_degree  \
# 28                    Low                             Medium
# 29                    Low                             Medium
# 30                    Low                             Medium
# 31                    Low                             Medium
# 32                    Low                             Medium
# 33                    Low                             Medium
# 34                    Low                             Medium
#
#                 method         F1-score             BAcc              EOp  \
# 28                 CPP   -0.054 (-6.5%)  -0.145 (-17.8%)    0.135 (59.0%)
# 29                 EPP  -0.139 (-16.7%)  -0.088 (-10.9%)  -0.038 (-16.5%)
# 30                 ROC   -0.012 (-1.4%)   -0.011 (-1.4%)  -0.115 (-50.3%)
# 31                PSTA   -0.001 (-0.1%)   -0.008 (-1.0%)  -0.127 (-55.7%)
# 32                FACT   -0.031 (-3.7%)   -0.035 (-4.2%)   0.348 (152.4%)
# ...
