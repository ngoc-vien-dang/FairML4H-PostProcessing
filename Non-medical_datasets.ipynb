# %%
import pickle
file_path = 'Trade-off_non_medical_data.pkl'
# Load the dictionary
with open(file_path, 'rb') as f:
    non_medical_df = pickle.load(f)

# %%
non_medical_df.keys()
# Out:
# dict_keys(['High_High', 'Low_High', 'Medium_Low', 'Medium_Medium', 'Overall_Overall'])

# %%
non_medical_df['High_High']
# Out:
#   class_imbalance_degree unprivileged_representation_degree  \
# 0                   High                               High
# 1                   High                               High
# 2                   High                               High
# 3                   High                               High
# 4                   High                               High
# 5                   High                               High
# 6                   High                               High
#
#                method         F1-score             BAcc              EOp  \
# 0                 CPP   -0.022 (-4.2%)   -0.013 (-1.9%)  -0.020 (-19.8%)
# 1                 EPP  -0.114 (-22.0%)   -0.023 (-3.4%)  -0.072 (-71.3%)
# 2                 ROC     0.033 (6.3%)    0.172 (24.6%)  -0.081 (-80.2%)
# 3                PSTA     0.010 (2.0%)     0.007 (1.0%)  -0.018 (-18.2%)
# 4                FACT  -0.487 (-93.8%)  -0.238 (-34.1%)    0.023 (22.5%)
# ...

# %%
non_medical_df['Low_High']
# Out:
#    class_imbalance_degree unprivileged_representation_degree  \
# 7                     Low                               High
# 8                     Low                               High
# 9                     Low                               High
# 10                    Low                               High
# 11                    Low                               High
# 12                    Low                               High
# 13                    Low                               High
#
#                 method         F1-score             BAcc              EOp  \
# 7                  CPP   -0.002 (-0.2%)   -0.020 (-3.0%)     0.009 (4.0%)
# 8                  EPP   -0.018 (-2.5%)  -0.069 (-10.4%)  -0.107 (-52.4%)
# 9                  ROC   -0.030 (-4.2%)   -0.007 (-1.1%)  -0.050 (-24.3%)
# 10                PSTA     0.009 (1.3%)   -0.003 (-0.4%)  -0.039 (-19.0%)
# 11                FACT   -0.050 (-6.8%)   -0.030 (-4.3%)  -0.029 (-14.5%)
# ...

# %%
non_medical_df['Medium_Low']
# Out:
#    class_imbalance_degree unprivileged_representation_degree  \
# 14                 Medium                                Low
# 15                 Medium                                Low
# 16                 Medium                                Low
# 17                 Medium                                Low
# 18                 Medium                                Low
# 19                 Medium                                Low
# 20                 Medium                                Low
#
#                 method         F1-score             BAcc              EOp  \
# 14                 CPP   -0.057 (-8.3%)  -0.087 (-11.5%)  -0.054 (-36.9%)
# 15                 EPP   -0.041 (-6.0%)   -0.060 (-7.7%)  -0.037 (-25.4%)
# 16                 ROC   -0.036 (-4.4%)     0.015 (2.4%)  -0.014 (-10.4%)
# 17                PSTA   -0.008 (-1.1%)   -0.032 (-4.0%)  -0.032 (-21.9%)
# 18                FACT  -0.318 (-42.0%)  -0.162 (-21.7%)  -0.041 (-27.5%)
# ...

# %%
non_medical_df['Medium_Medium']
# Out:
#    class_imbalance_degree unprivileged_representation_degree  \
# 21                 Medium                             Medium
# 22                 Medium                             Medium
# 23                 Medium                             Medium
# 24                 Medium                             Medium
# 25                 Medium                             Medium
# 26                 Medium                             Medium
# 27                 Medium                             Medium
#
#                 method         F1-score             BAcc              EOp  \
# 21                 CPP  -0.072 (-10.5%)  -0.096 (-12.5%)    0.002 (29.3%)
# 22                 EPP   -0.044 (-6.4%)   -0.059 (-7.7%)  -0.068 (-57.7%)
# 23                 ROC   -0.037 (-4.7%)     0.015 (2.3%)  -0.058 (-40.4%)
# 24                PSTA   -0.007 (-1.0%)   -0.030 (-3.8%)  -0.059 (-38.9%)
# 25                FACT  -0.278 (-36.1%)  -0.143 (-19.4%)   0.249 (296.0%)
# ...
