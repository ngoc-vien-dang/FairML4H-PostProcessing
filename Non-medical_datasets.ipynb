# %%
import pandas as pd
import numpy as np
import os
import pickle

file_path = 'Add_XGB_DNN_Trade-off_overall_data_non_medical.pkl'
with open(file_path, 'rb') as f:
    non_medical_df = pickle.load(f)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
non_medical_df['Overall_Overall'][['class_imbalance_degree', 'unprivileged_representation_degree','method', 'F1-score', 'BAcc', 'EOp', 'EOd']]
# Out:
#    class_imbalance_degree unprivileged_representation_degree   method  \
# 64                Overall                            Overall      CPP
# 65                Overall                            Overall      EPP
# 70                Overall                            Overall      ROC
# 69                Overall                            Overall     PSTA
# 66                Overall                            Overall     FACT
# 67                Overall                            Overall    GSTAR
# 68                Overall                            Overall      MAB
# 71                Overall                            Overall  Average
#
#            F1-score             BAcc              EOp              EOd
# 64   -0.025 (-3.8%)   -0.046 (-6.3%)     0.008 (8.8%)    0.041 (35.6%)
# 65  -0.065 (-10.5%)   -0.044 (-6.1%)  -0.062 (-46.5%)  -0.077 (-49.4%)
# 70   -0.022 (-2.7%)     0.040 (5.4%)  -0.039 (-31.9%)    -0.012 (2.9%)
# ...

# %%
non_medical_df['High_High'][['class_imbalance_degree', 'unprivileged_representation_degree','method', 'F1-score', 'BAcc', 'EOp', 'EOd']]
# Out:
#   class_imbalance_degree unprivileged_representation_degree   method  \
# 1                   High                               High      CPP
# 2                   High                               High      EPP
# 7                   High                               High      ROC
# 6                   High                               High     PSTA
# 3                   High                               High     FACT
# 4                   High                               High    GSTAR
# 5                   High                               High      MAB
# 8                   High                               High  Average
#
#           F1-score             BAcc              EOp              EOd
# 1   -0.015 (-2.8%)   -0.011 (-1.5%)  -0.029 (-29.9%)  -0.036 (-34.5%)
# 2  -0.147 (-26.2%)   -0.032 (-4.4%)  -0.062 (-64.8%)  -0.081 (-77.2%)
# 7     0.006 (1.3%)    0.140 (19.2%)  -0.065 (-69.7%)    0.044 (43.8%)
# ...

# %%
non_medical_df['Low_High'][['class_imbalance_degree', 'unprivileged_representation_degree','method', 'F1-score', 'BAcc', 'EOp', 'EOd']]
# Out:
#    class_imbalance_degree unprivileged_representation_degree   method  \
# 28                    Low                               High      CPP
# 29                    Low                               High      EPP
# 34                    Low                               High      ROC
# 33                    Low                               High     PSTA
# 30                    Low                               High     FACT
# 31                    Low                               High    GSTAR
# 32                    Low                               High      MAB
# 35                    Low                               High  Average
#
#            F1-score            BAcc              EOp              EOd
# 28     0.003 (0.4%)  -0.015 (-2.2%)    0.019 (11.1%)    0.067 (36.9%)
# 29   -0.016 (-2.2%)  -0.057 (-8.7%)  -0.105 (-56.5%)  -0.132 (-59.5%)
# 34   -0.028 (-3.8%)  -0.005 (-0.8%)  -0.047 (-25.5%)  -0.072 (-31.8%)
# ...

# %%
non_medical_df['Medium_Low'][['class_imbalance_degree', 'unprivileged_representation_degree','method', 'F1-score', 'BAcc', 'EOp', 'EOd']]
# Out:
#    class_imbalance_degree unprivileged_representation_degree   method  \
# 46                 Medium                                Low      CPP
# 47                 Medium                                Low      EPP
# 52                 Medium                                Low      ROC
# 51                 Medium                                Low     PSTA
# 48                 Medium                                Low     FACT
# 49                 Medium                                Low    GSTAR
# 50                 Medium                                Low      MAB
# 53                 Medium                                Low  Average
#
#            F1-score             BAcc              EOp              EOd
# 46   -0.037 (-5.5%)  -0.093 (-12.8%)    0.037 (32.2%)    0.104 (88.8%)
# 47   -0.057 (-7.7%)   -0.047 (-6.2%)  -0.030 (-20.1%)  -0.030 (-16.8%)
# 52   -0.035 (-4.3%)     0.010 (1.4%)    -0.004 (0.5%)    0.013 (20.5%)
# ...

# %%
non_medical_df['Medium_Medium'][['class_imbalance_degree', 'unprivileged_representation_degree','method', 'F1-score', 'BAcc', 'EOp', 'EOd']]
# Out:
#    class_imbalance_degree unprivileged_representation_degree   method  \
# 55                 Medium                             Medium      CPP
# 56                 Medium                             Medium      EPP
# 61                 Medium                             Medium      ROC
# 60                 Medium                             Medium     PSTA
# 57                 Medium                             Medium     FACT
# 58                 Medium                             Medium    GSTAR
# 59                 Medium                             Medium      MAB
# 62                 Medium                             Medium  Average
#
#            F1-score             BAcc              EOp              EOd
# 55   -0.049 (-7.2%)   -0.066 (-8.7%)    0.004 (21.9%)    0.030 (51.1%)
# 56   -0.041 (-5.9%)   -0.041 (-5.3%)  -0.050 (-44.6%)  -0.063 (-44.2%)
# 61   -0.032 (-3.9%)     0.013 (1.8%)  -0.040 (-32.8%)  -0.031 (-21.1%)
# ...
