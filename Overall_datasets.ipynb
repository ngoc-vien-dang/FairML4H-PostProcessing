# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/2024/Project_5/Results')
# Out:
# Mounted at /content/drive

# %%
import pickle
file_path = 'Trade-off_overall_data.pkl'
# Load the dictionary
with open(file_path, 'rb') as f:
    overall_df = pickle.load(f)

# %%
overall_df['High_High']
# Out:
#   class_imbalance_degree unprivileged_representation_degree  \
# 0                   High                               High
# 1                   High                               High
# 2                   High                               High
# 3                   High                               High
# 4                   High                               High
# 5                   High                               High
# 6                   High                               High
#
#                method         F1-score             BAcc              EOp  \
# 0                 CPP   -0.042 (-7.6%)   -0.038 (-5.0%)  -0.038 (-25.1%)
# 1                 EPP  -0.140 (-25.7%)  -0.084 (-11.0%)  -0.165 (-75.8%)
# 2                 ROC   -0.008 (-1.3%)     0.046 (6.7%)  -0.156 (-74.6%)
# 3                PSTA   -0.017 (-3.0%)     0.000 (0.0%)  -0.073 (-34.8%)
# 4                FACT  -0.532 (-97.5%)  -0.262 (-35.0%)  -0.160 (-58.5%)
# ...

# %%
overall_df['High_Low']
# Out:
#    class_imbalance_degree unprivileged_representation_degree  \
# 7                    High                                Low
# 8                    High                                Low
# 9                    High                                Low
# 10                   High                                Low
# 11                   High                                Low
# 12                   High                                Low
# 13                   High                                Low
#
#                 method          F1-score             BAcc               EOp  \
# 7                  CPP    -0.001 (-0.4%)   -0.009 (-1.2%)   -0.027 (-48.3%)
# 8                  EPP    -0.005 (-2.5%)   -0.015 (-2.0%)   -0.019 (-33.2%)
# 9                  ROC    -0.007 (-3.6%)     0.001 (0.1%)   -0.018 (-33.1%)
# 10                PSTA    -0.002 (-1.0%)     0.000 (0.0%)   -0.035 (-64.5%)
# 11                FACT  -0.178 (-100.0%)  -0.229 (-31.4%)  -0.053 (-100.0%)
# ...

# %%
overall_df['High_Medium']
# Out:
#    class_imbalance_degree unprivileged_representation_degree  \
# 14                   High                             Medium
# 15                   High                             Medium
# 16                   High                             Medium
# 17                   High                             Medium
# 18                   High                             Medium
# 19                   High                             Medium
# 20                   High                             Medium
#
#                 method         F1-score             BAcc              EOp  \
# 14                 CPP   -0.035 (-7.7%)   -0.046 (-6.3%)  -0.149 (-67.9%)
# 15                 EPP  -0.050 (-12.1%)   -0.048 (-6.5%)  -0.155 (-73.8%)
# 16                 ROC   -0.011 (-2.9%)   -0.003 (-0.5%)  -0.138 (-67.1%)
# 17                PSTA   -0.013 (-3.2%)   -0.002 (-0.3%)  -0.142 (-64.7%)
# 18                FACT  -0.408 (-99.8%)  -0.242 (-32.6%)  -0.188 (-99.2%)
# ...

# %%
overall_df['Medium_Low']
# Out:
#    class_imbalance_degree unprivileged_representation_degree  \
# 35                 Medium                                Low
# 36                 Medium                                Low
# 37                 Medium                                Low
# 38                 Medium                                Low
# 39                 Medium                                Low
# 40                 Medium                                Low
# 41                 Medium                                Low
#
#                 method         F1-score             BAcc              EOp  \
# 35                 CPP   -0.057 (-8.3%)  -0.087 (-11.5%)  -0.054 (-36.9%)
# 36                 EPP   -0.041 (-6.0%)   -0.060 (-7.7%)  -0.037 (-25.4%)
# 37                 ROC   -0.036 (-4.4%)     0.015 (2.4%)  -0.014 (-10.4%)
# 38                PSTA   -0.008 (-1.1%)   -0.032 (-4.0%)  -0.032 (-21.9%)
# 39                FACT  -0.318 (-42.0%)  -0.162 (-21.7%)  -0.041 (-27.5%)
# ...

# %%
overall_df['Medium_Medium']
# Out:
#    class_imbalance_degree unprivileged_representation_degree  \
# 42                 Medium                             Medium
# 43                 Medium                             Medium
# 44                 Medium                             Medium
# 45                 Medium                             Medium
# 46                 Medium                             Medium
# 47                 Medium                             Medium
# 48                 Medium                             Medium
#
#                 method         F1-score             BAcc              EOp  \
# 42                 CPP  -0.072 (-10.5%)  -0.096 (-12.5%)    0.002 (29.3%)
# 43                 EPP   -0.044 (-6.4%)   -0.059 (-7.7%)  -0.068 (-57.7%)
# 44                 ROC   -0.037 (-4.7%)     0.015 (2.3%)  -0.058 (-40.4%)
# 45                PSTA   -0.007 (-1.0%)   -0.030 (-3.8%)  -0.059 (-38.9%)
# 46                FACT  -0.278 (-36.1%)  -0.143 (-19.4%)   0.249 (296.0%)
# ...
